# %%
import pandas as pd

# %%
data = {
    'name': ['Brinda', 'Mahek', 'Jiya'],
    'age': [16, 17, 17],
    'enrollment_number': [7012, 7008, 7030]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      name  age  enrollment_number
# 0  Brinda   16               7012
# 1   Mahek   17               7008
# 2    Jiya   17               7030

# %%
df
# Out:
#      name  age  enrollment_number
# 0  Brinda   16               7012
# 1   Mahek   17               7008
# 2    Jiya   17               7030

# %%
df['added_column'] = [1, 2, 3]

# %%
df
# Out:
#      name  age  enrollment_number  added_column
# 0  Brinda   16               7012             1
# 1   Mahek   17               7008             2
# 2    Jiya   17               7030             3

# %%
filtered_df = df[(df['age'] > 16) & (df['enrollment_number'] > 7013)]

# %%
filtered_df
# Out:
#    name  age  enrollment_number  added_column
# 2  Jiya   17               7030             3

# %% [markdown]
# ----
# # Practical - 3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV into DataFrame
df = pd.read_csv("demo.csv")

# Display first few rows
print("📄 First 5 rows:")
print(df.head())

# Summary statistics
print("\n📊 Summary Statistics:")
print(df.describe())
# Out:
# 📄 First 5 rows:
#      Name  Age Department  Salary
# 0   Mahek   25         HR   50000
# 1    Jiya   30         IT   60000
# 2   Marva   28    Finance   55000
# 3  Dhruvi   35         IT   65000
# 4   Hetal   22         HR   48000
#
# 📊 Summary Statistics:
#              Age        Salary
# count   5.000000      5.000000
# mean   28.000000  55600.000000
# std     4.949747   7021.395873
# min    22.000000  48000.000000
# 25%    25.000000  50000.000000
# 50%    28.000000  55000.000000
# 75%    30.000000  60000.000000
# max    35.000000  65000.000000

# %%
# Bar chart: Average salary per department
avg_salary = df.groupby('Department')['Salary'].mean()
avg_salary.plot(kind='bar', title='Average Salary by Department', color='skyblue')
plt.ylabel('Salary')
plt.xlabel('Department')
plt.tight_layout()
plt.show()

# %%
# Line plot: Salary vs Age
df.plot(x='Age', y='Salary', kind='line', marker='o', title='Salary vs Age')
plt.ylabel('Salary')
plt.xlabel('Age')
plt.tight_layout()
plt.show()

# %%
# Pie chart for employee count by department
dept_counts = df['Department'].value_counts()
dept_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, title='Employees per Department', ylabel='')
plt.tight_layout()
plt.show()

# %%
# Scatter plot: Age vs Salary
df.plot(kind='scatter', x='Age', y='Salary', color='green', title='Age vs Salary')
plt.grid(True)
plt.tight_layout()
plt.show()
